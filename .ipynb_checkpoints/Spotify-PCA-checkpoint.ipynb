# %%
# PCA przeprowadzone na bazie 20 krajów z różnych kontynentów. Gdzie cechami każdego kraju jest jego położenie geograficzne, 
# ludność, trzy najbardziej popularne gatunki muzyczne, poziomy parametrów opisujących utwory muzyczne z top100 najpopluarniejszych
# takie jak: danceability, energy, acousticness, instrumentalness, liveness, tempo.

# %%
import pandas as pd 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
import os

# %matplotlib inline

# %%
df_countries = pd.read_csv(os.getcwd()+'\data\country_data_pca.csv')

# %%
df_countries
# Out:
#    Country         Region  Population  Latitude  Longitude     Top 1 genre  \
# 0       PL        East_EU    37970000   52.2297    21.0122  polish hip hop
# 1       US  NORTH_AMERICA   328200000   47.7511   120.7401             rap
# 2       GB        WEST_EU    66650000   51.5074     0.1278             pop
# 3       BR  SOUTH_AMERICA   211000000   22.9068    43.1729   sentanejo pop
# 4       ES        WEST_EU    46940000   40.4168     3.7038           latin
# 5       JP           ASIA   126300000   35.6762   139.6503           J-pop
# 6       CZ        East_EU    10650000   50.0755    14.4378             pop
# 7       HU        East_EU     9773000   47.2933    19.0305             pop
# 8       DE        WEST_EU    83020000   52.5200    13.4050  german hip hop
# 9       FR        WEST_EU    67060000   48.8566     2.3522  french hip hop
# 10      MX  NORTH_AMERICA   127600000   23.6345   102.5528           latin
# 11      CA  NORTH_AMERICA    37590000   43.6532    79.3832             pop
# 12      PT        WEST_EU    10280000   38.7223     9.1393    hip hop tuga
# 13      AR  SOUTH_AMERICA    44940000   34.6037    58.3816           latin
# 14      TW           ASIA    23570000   25.0330   121.5654        mandopop
# 15      HK           ASIA     7507000   22.3193   114.1694           C-pop
# 16      SK        East_EU     5450000   48.1486    17.1077             pop
#
#                 Top 2 genre    Top 3 genre  Danceability  Energy  \
# 0               polish trap            pop        0.7161  0.6560
# 1                       pop    melodic rap        0.7274  0.5750
# 2                 dance pop            rap        0.6734  0.6491
# 3   sentanejo universitario      sentanejo        0.6628  0.7218
# 4               trap latino      reggaeton        0.7503  0.7271
# 5                anime rock         J-rock        0.5723  0.7367
# 6              czsk hip hop      dance pop        0.6837  0.6527
# 7                 dance pop  hungarian pop        0.7038  0.6500
# 8                       pop      dance pop        0.7230  0.6912
# 9               pop urbaine   rap francais        0.7475  0.6417
# 10                reggaeton    trap latino        0.7404  0.6892
# 11                      rap    melodic rap        0.7147  0.5863
# 12                      pop            rap        0.7110  0.6235
# 13              trap latino      reggaeton        0.7313  0.7139
# 14               taiwan pop            pop        0.5717  0.5211
# 15                 cantopop            pop        0.5845  0.5476
# 16                dance pop   czsk hip hop        0.6942  0.6336
#
#     Acousticness  Instrumentalness  Liveness   Tempo
# 0         0.2957            0.0050    0.0050  0.1674
# 1         0.2443            0.0120    0.0120  0.1619
# 2         0.2189            0.0087    0.0087  0.1662
# 3         0.3490            0.0000    0.0000  0.3794
# 4         0.2171            0.0005    0.0005  0.1576
# 5         0.1877            0.0014    0.0014  0.1889
# 6         0.2070            0.0050    0.0050  0.1855
# 7         0.2306            0.0102    0.0102  0.1672
# 8         0.2050            0.0144    0.0144  0.1507
# 9         0.3442            0.0102    0.0102  0.1492
# 10        0.2146            0.0020    0.0020  0.1548
# 11        0.2534            0.0117    0.0117  0.1770
# 12        0.3194            0.0109    0.0109  0.1429
# 13        0.2211            0.0016    0.0016  0.1572
# 14        0.4617            0.0020    0.0020  0.1373
# 15        0.4277            0.0013    0.0013  0.1475
# 16        0.2608            0.0082    0.0082  0.1708

# %%
sns.pairplot(df_countries, hue='Region')

# %%
y_region = df_countries.loc[:,'Region'].values

# %%
y_region
# Out:
# array(['East_EU', 'NORTH_AMERICA', 'WEST_EU', 'SOUTH_AMERICA', 'WEST_EU',
#        'ASIA', 'East_EU', 'East_EU', 'WEST_EU', 'WEST_EU',
#        'NORTH_AMERICA', 'NORTH_AMERICA', 'WEST_EU', 'SOUTH_AMERICA',
#        'ASIA', 'ASIA', 'East_EU'], dtype=object)

# %%
x_features_numerical = df_countries.loc[:, ['Danceability','Energy', 'Acousticness', 'Instrumentalness', 'Liveness', 'Tempo']].values

# %%
pca_countries_regions = PCA(n_components=2)

# %%
pca_countries_regions.explained_variance_ratio_
# Out:
# array([0.57849746, 0.23606404])

# %%
X_pca = pca_countries_regions.fit_transform(x_features_numerical)

# %%
principal_df_regions = pd.DataFrame(data = X_pca ,columns = ['principal component 1', 'principal component 2'])

# %%
principal_df_regions = pd.concat([principal_df_regions, df_countries[['Region','Country']]], axis = 1)
principal_df_regions
# Out:
#     principal component 1  principal component 2         Region Country
# 0                0.002729              -0.007373        East_EU      PL
# 1                0.001234              -0.062993  NORTH_AMERICA      US
# 2               -0.036931              -0.010778        WEST_EU      GB
# 3                0.019611               0.219666  SOUTH_AMERICA      BR
# 4               -0.106771              -0.008830        WEST_EU      ES
# 5               -0.069922               0.078217           ASIA      JP
# 6               -0.052600               0.000572        East_EU      CZ
# 7               -0.039720              -0.018367        East_EU      HU
# 8               -0.087199              -0.024429        WEST_EU      DE
# 9                0.036590              -0.030979        WEST_EU      FR
# 10              -0.085244              -0.025493  NORTH_AMERICA      MX
# 11               0.006377              -0.039641  NORTH_AMERICA      CA
# 12               0.040760              -0.035949        WEST_EU      PT
# 13              -0.089805              -0.007787  SOUTH_AMERICA      AR
# 14               0.255280              -0.010698           ASIA      TW
# 15               0.210181              -0.001260           ASIA      HK
# 16              -0.004570              -0.013878        East_EU      SK

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 Component PCA', fontsize = 20)


region_targets = ['East_EU', 'WEST_EU', 'NORTH_AMERICA', 'SOUTH_AMERICA', 'ASIA']
colors = ['r', 'g', 'b', 'c', 'm']
for target, color in zip(region_targets,colors):
    indicesToKeep = principal_df_regions['Region'] == target
    ax.scatter(principal_df_regions.loc[indicesToKeep, 'principal component 1']
               , principal_df_regions.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
for row in principal_df_regions.values:
    ax.annotate(row[3], (row[0],row[1]))
ax.legend(region_targets)
ax.grid()
